# %%
import pandas as pd

# %% [markdown]
# ## CARGAMOS EL ARCHIVO

# %%
file = pd.read_csv('Doctors_info.csv')
file
# Out:
#                                       Name     Especialist  \
# 0                  Lic. Andrea Pérez Pérez  Fisioterapeuta
# 1     Lic. Carlos Daniel Láscarez Baltazar  Fisioterapeuta
# 2         Lic. César de Jesús Roque Campos  Fisioterapeuta
# 3                                      NaN             NaN
# 4                                      NaN             NaN
# ...                                    ...             ...
# 1262   Tec. Rehab. Beatriz Martinez Zavala  Fisioterapeuta
# 1263                   Africa Navarro Lara  Fisioterapeuta
# 1264                  Jesus Miranda Moreno  Fisioterapeuta
# 1265                       Eugenia Maretto  Fisioterapeuta
# 1266                         Jessica Ponce  Fisioterapeuta
#
#                                                   Focus  \
# 0     (Traumatológica, Terapias manuales, Terapia fí...
# 1     (Deportiva, Geriátrica, Traumatológica, Terapi...
# 2     (Deportiva, Traumatológica, Terapias manuales,...
# ...

# %% [markdown]
# # LIMPIEZA
# Lo principal es quitar las filas que no contienen ningun dato

# %%
df = file.dropna(subset = ['Name'])
df
# Out:
#                                       Name  \
# 0                  Lic. Andrea Pérez Pérez
# 1     Lic. Carlos Daniel Láscarez Baltazar
# 2         Lic. César de Jesús Roque Campos
# 5                            Kenko Medical
# 6           Lic. Silvia Hernandez Leonardo
# ...                                    ...
# 1262   Tec. Rehab. Beatriz Martinez Zavala
# 1263                   Africa Navarro Lara
# 1264                  Jesus Miranda Moreno
# 1265                       Eugenia Maretto
# 1266                         Jessica Ponce
#
#                                       Especialist  \
# 0                                  Fisioterapeuta
# 1                                  Fisioterapeuta
# 2                                  Fisioterapeuta
# 5     Fisioterapeuta, Médico de familia, Pediatra
# 6                                  Fisioterapeuta
# ...                                           ...
# 1262                               Fisioterapeuta
# ...

# %%
ndf = df.drop(columns = ['Pagina'])
ndf
# Out:
#                                       Name  \
# 0                  Lic. Andrea Pérez Pérez
# 1     Lic. Carlos Daniel Láscarez Baltazar
# 2         Lic. César de Jesús Roque Campos
# 5                            Kenko Medical
# 6           Lic. Silvia Hernandez Leonardo
# ...                                    ...
# 1262   Tec. Rehab. Beatriz Martinez Zavala
# 1263                   Africa Navarro Lara
# 1264                  Jesus Miranda Moreno
# 1265                       Eugenia Maretto
# 1266                         Jessica Ponce
#
#                                       Especialist  \
# 0                                  Fisioterapeuta
# 1                                  Fisioterapeuta
# 2                                  Fisioterapeuta
# 5     Fisioterapeuta, Médico de familia, Pediatra
# 6                                  Fisioterapeuta
# ...                                           ...
# 1262                               Fisioterapeuta
# ...

# %%
ndf.to_excel('Doctors_Data_Clean.xlsx', index = False)
ndf.to_csv('Doctors_Data_Clean.csv', index = False)
